# %% [markdown]
# # LOADING DATASET

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DoubleType, BooleanType, LongType

# %%
from pyspark.sql.types import *

structure = StructType([
        StructField("overall", DoubleType(), True),
        StructField("vote", StringType(), True),
        StructField("verified", BooleanType(), True),
        StructField("reviewTime", StringType(), True),
        StructField("reviewerID", StringType(), True),
        StructField("asin", StringType(), True),
        StructField("reviewerName", StringType(), True),
        StructField("reviewText", StringType(), True),
        StructField("summary", StringType(), True),
        StructField("unixReviewTime", LongType(), True),
])

# %%
mongo_uri = "mongodb://localhost:27017/projet_amazon"

# %%
import os

os.environ['HADOOP_HOME'] = "C:\\hadoop"  # or the actual path where hadoop is installed
os.environ['PATH'] += os.pathsep + os.path.join(os.environ['HADOOP_HOME'], 'bin')

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("AmazonToMongoDB") \
    .config("spark.mongodb.write.connection.uri", mongo_uri) \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:3.0.1") \
    .getOrCreate()

# %%
df = spark.read.json("All_Amazon_Review.json", schema=structure)

# %%
df.printSchema()
# Out:
# root
#  |-- overall: double (nullable = true)
#  |-- vote: string (nullable = true)
#  |-- verified: boolean (nullable = true)
#  |-- reviewTime: string (nullable = true)
#  |-- reviewerID: string (nullable = true)
#  |-- asin: string (nullable = true)
#  |-- reviewerName: string (nullable = true)
#  |-- reviewText: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- unixReviewTime: long (nullable = true)

# %%
df.show(20)
# Out:
# +-------+----+--------+-----------+--------------+----------+----------------+--------------------+--------------------+--------------+
# |overall|vote|verified| reviewTime|    reviewerID|      asin|    reviewerName|          reviewText|             summary|unixReviewTime|
# +-------+----+--------+-----------+--------------+----------+----------------+--------------------+--------------------+--------------+
# |    1.0|NULL|   false|12 11, 2015|A27BTSGLXK2C5K|B017O9P72A|Jacob M. Wessler|Alexa is not able...|VERY Buggy, doesn...|    1449792000|
# |    4.0|   5|   false| 12 8, 2015|A27ZJ1NCBFP1HZ|B017O9P72A|            Greg|Alexa works great...|      So Far So Good|    1449532800|
# |    1.0|  11|   false| 12 7, 2015| ACCQIOZMFN4UK|B017O9P72A|        Da-Gr8-1|Weak!!\n\nAlexa d...|         Time waster|    1449446400|
# |    2.0|NULL|   false| 12 5, 2015|A3KUPJ396OQF78|B017O9P72A|   Larry Russlin|Can only control ...|               Buggy|    1449273600|
# |    1.0|   2|   false| 02 2, 2018|A1U1RE1ZI19E1H|B017O9P72A|         Rebekah|this worked great...|     stopped working|    1517529600|
# |    5.0|NULL|   false|01 15, 2018|A3TXR8GLKS19RE|B017O9P72A|           Nello|         Great skill|               Great|    1515974400|
# |    1.0|   4|   false| 01 5, 2018| AVIWE1LJXCG77|B017O9P72A|    Pete Johnson|Pretty crappy. Wo...|        Returning to|    1515110400|
# |    1.0|   2|   false| 01 4, 2018|A1FOHYK23FJ6CN|B017O9P72A|L. Ray Humphreys|Not happy. Can no...|Can not connect t...|    1515024000|
# |    1.0|   5|   false|12 30, 2017|A1RRDX9AOST1AN|B017O9P72A|           Viola|Can not connect a...|Connecting is a n...|    1514592000|
# |    1.0|   5|   false|12 29, 2017| AA4DHYT5YSSIT|B017O9P72A|       angie anj|The service works...|       Does not work|    1514505600|
# |    3.0|   9|   false|12 29, 2017|A3TYO7I2GSCH4X|B017O9P72A| Amazon Customer|The LifX bulb is ...|      Almost awesome|    1514505600|
# |    5.0|   2|   false|12 25, 2017|A3KWZMO1A9TO3Z|B017O9P72A| Amazon Customer|So easy to connec...|     This is awesome|    1514160000|
# |    5.0|   2|   false|12 18, 2017|A1QBG1TTQZGJNM|B017O9P72A|         Artyhow|I use &ldquo;Echo...|      Alexa and LIFX|    1513555200|
# |    2.0|   6|   false|11 28, 2017|A2NGABQTU93H28|B017O9P72A|           noura|Can&rsquo;t conne...|          Really bad|    1511827200|
# |    5.0|NULL|   false|11 24, 2017|A2LNJJWW2TLL00|B017O9P72A|         jarhead|I haven't had any...|            Love it!|    1511481600|
# |    1.0|   3|   false|11 23, 2017|A1M5UIUZ2P5FFO|B017O9P72A| Amazon Customer|This app forces y...|   Use the other app|    1511395200|
# |    1.0|   2|   false|11 10, 2017| AE5S7XRYMZ15P|B017O9P72A|    Karim Moussa|Red all steps and...|I can&rsquo;t con...|    1510272000|
# |    4.0|   5|   false|10 19, 2017|A18JLUE8V4G7TX|B017O9P72A|     Uncle Rusty|This skill works ...|This skill works ...|    1508371200|
# |    1.0|NULL|   false|09 13, 2017|A1E35W9YOVAH1G|B017O9P72A| Amazon Customer|Who would think y...|            Pathetic|    1505260800|
# |    3.0|   3|   false|08 23, 2017|A2OPRIKEHM8WUI|B017O9P72A|              RS|Lifx is a weird w...|            Not bad.|    1503446400|
# +-------+----+--------+-----------+--------------+----------+----------------+--------------------+--------------------+--------------+
# only showing top 20 rows

# %% [markdown]
# # CLEANING DATASET

# %%
df.withColumn("vote", df.vote.cast(IntegerType()))
# Out:
# DataFrame[overall: double, vote: int, verified: boolean, reviewTime: string, reviewerID: string, asin: string, reviewerName: string, reviewText: string, summary: string, unixReviewTime: bigint]

# %%
df = df.fillna({
    "overall": 0.0,
    "vote": 0,
    "verified": False,
    "reviewTime": "",
    "reviewerID": "",
    "asin": "",
    "reviewerName": "Anonymous",
    "reviewText": "",
    "summary": "",
    "unixReviewTime": ""
})

# %%
from pyspark.sql.functions import regexp_replace, col, lower

df = df.withColumn("reviewText", regexp_replace(col("reviewText"), r"[^\w\s]+", ""))
df = df.withColumn("reviewText", lower(col("reviewText")))
df = df.withColumn("summary", regexp_replace(col("summary"), r"[^\w\s]+", ""))
df = df.withColumn("summary", lower(col("summary")))

# %%
from pyspark.sql.functions import when

df = df.withColumn("verified", when(df.verified == "True", 1).otherwise(0))

# %%
pandas_df = df.limit(50).toPandas()
display(pandas_df)
# Out:
#     overall vote  verified   reviewTime      reviewerID        asin  \
# 0       1.0    0         0  12 11, 2015  A27BTSGLXK2C5K  B017O9P72A
# 1       4.0    5         0   12 8, 2015  A27ZJ1NCBFP1HZ  B017O9P72A
# 2       1.0   11         0   12 7, 2015   ACCQIOZMFN4UK  B017O9P72A
# 3       2.0    0         0   12 5, 2015  A3KUPJ396OQF78  B017O9P72A
# 4       1.0    2         0   02 2, 2018  A1U1RE1ZI19E1H  B017O9P72A
# 5       5.0    0         0  01 15, 2018  A3TXR8GLKS19RE  B017O9P72A
# 42      1.0    6         0   01 3, 2017  A2RDT3XZJ3KO8V  B017O9P72A
# 43      1.0    7         0   01 2, 2017  A1WP68243XC735  B017O9P72A
# 44      5.0    3         0   01 1, 2017   AINFUA7ZDOCXC  B017O9P72A
# 45      4.0    3         0  12 30, 2016  A25ZBRVCSH2854  B017O9P72A
# 46      1.0    2         0  12 30, 2016  A2NQLB39X8R6VM  B017O9P72A
# 47      1.0    4         0  12 29, 2016  A2A05GWHUW863P  B017O9P72A
# 48      1.0    5         0  12 29, 2016  A2X121FSZNDNQD  B017O9P72A
# 49      2.0    0         0  12 29, 2016  A2VIMSLCBS1SIX  B017O9P72A
#
#          reviewerName                                         reviewText  \
# 0    Jacob M. Wessler  alexa is not able to control my lights if i as...
# 1                Greg  alexa works great for me so far but im also on...
# 2            Da-Gr8-1  weak\n\nalexa doesnt even recognize the name l...
# 3       Larry Russlin  can only control one of two bulbs from one of ...
# 4             Rebekah  this worked great then randomly stopped please...
# 5               Nello                                        great skill
# 6        Pete Johnson        pretty crappy wonrsquot connect with alexis
# 7    L. Ray Humphreys      not happy can not connect to alexa regardless
# 8               Viola  can not connect a hue lights to alexa linked t...
# 9           angie anj  the service works with google home but doesnt ...
# 10    Amazon Customer  the lifx bulb is awesome this skill is not so ...
# 11    Amazon Customer  so easy to connect and irsquom having way too ...
# 12            Artyhow  i use ldquoechordquo as the wake word  i say l...
# 13              noura                    canrsquot connect lifx to alexa
# 14            jarhead  i havent had any issues  with this skill like ...
# 15    Amazon Customer  this app forces you to use the old invocation ...
# 16       Karim Moussa              red all steps and did all not working
# 17        Uncle Rusty  this skill works just fine though i think a lo...
# 18    Amazon Customer  who would think you would have to spend so muc...
# 19                 RS  lifx is a weird word to say  be so much better...
# 20            edupunk  i have to tell alexa to tell lifx to do things...
# 21            RobertP                              the title says it all
# 22     Mageswari Babu                                               good
# 23    Amazon Customer  im giving this five stars because i can now ju...
# 24                  T  once i got used to it to how to say the comman...
# 25    Amazon Customer  so far i have no issues connecting lifx bulbs ...
# 26            Chasser  as others have stated you cannot control the l...
# 27               G.B.  when giving instructions alexa asks which ligh...
# 28            DiepJDS                                        messagenull
# 29          GamingGuy  i wish i was able to say  alexa tell lifx net ...
# 30      Casey Michael                   unable to link account pointless
# 31  Alessandro Fadini  when trying to link an account a line of code ...
# 32       Tushar Joshi  logout of your lifx account and link it fron a...
# 33              Trent  i get an error when trying to link my account ...
# 34             Andrew  cant authorize my account gives me an error us...
# 35    Amazon Customer  remember there are two skills you must setup f...
# 36    Michele M Young  thanks to another reviewer i finally figured t...
# 37              Jacob  ive had the lifx bulbs for two weeks and they ...
# 38                Agi  i linked lifx through  the alexa smart home wi...
# 39      Ashley Walker  i had this enabled but then disabled it  upon ...
# 40     Jack Caravanos  i love my lifx bulbs but this skill still need...
# 41       AuggieDoggie  null message fixed by logging out log out and ...
# 42          C. Wright  will not authorize gettting a null message lik...
# 43        David Allen  horrific lights lose link at least once per da...
# 44         Kimberly G  love my lifx bulbs i have them in my bedroom a...
# 45       Charles Hall  see joey kot dec 28th review  once i logged ou...
# 46               Mark  cannot authorize on my android tablet  it give...
# 47               Hilo  doesnt work on android when you try to authori...
# 48    Jennifer McCabe                   cant link account just says null
# 49         SNITBENDER  good skill but many times some lights dont go ...
#
#                                               summary  unixReviewTime
# 0                              very buggy doesnt work      1449792000
# 1                                      so far so good      1449532800
# 2                                         time waster      1449446400
# 3                                               buggy      1449273600
# 4                                     stopped working      1517529600
# 5                                               great      1515974400
# 6                                        returning to      1515110400
# 7                             can not connect to echo      1515024000
# 8                               connecting is a no go      1514592000
# 9                                       does not work      1514505600
# 10                                     almost awesome      1514505600
# 11                                    this is awesome      1514160000
# 12                                     alexa and lifx      1513555200
# 13                                         really bad      1511827200
# 14                                            love it      1511481600
# 15                                  use the other app      1511395200
# 16  i canrsquot connect to alexia connected to lif...      1510272000
# 17  this skill works just fine though i think a lo...      1508371200
# 18                                           pathetic      1505260800
# 19                                            not bad      1503446400
# 20                       commands need to get shorter      1500854400
# 21                        update breaks functionality      1500768000
# 22                       hooked it up today with ease      1498694400
# 23                                        works great      1491523200
# 24                                        works great      1490659200
# 25          takes more steps than other smart devices      1489708800
# 26                                             usless      1489363200
# 27                                    poorly executed      1489276800
# 28                                cannot link account      1488758400
# 29                                   great lights but      1488758400
# 30                   unable to link account pointless      1488585600
# 31                             linking account broken      1488240000
# 32                       works great null error fixed      1487548800
# 33                              error when connecting      1487376000
# 34                               cant link my account      1487289600
# 35                                        works great      1486944000
# 36                                     figured it out      1485302400
# 37                                   need to fix this      1485043200
# 38                             linking sccount failed      1484697600
# 39                                             issues      1483920000
# 40                    problems with colors and scenes      1483833600
# 41                        log out to fix null message      1483574400
# 42                               not working properly      1483401600
# 43                         too many connection errors      1483315200
# 44                 love lifxim now one of the jetsons      1483228800
# 45                                   fix null message      1483056000
# 46                                   cannot authorize      1483056000
# 47                                        doesnt work      1482969600
# 48                                               null      1482969600
# 49                                    works sometimes      1482969600

# %% [markdown]
# # LOADING DATA IN MONGODB

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Projet_Amazon") \
    .config("spark.jars", "c:\\spark\\jars\\mongo-spark-connector_2.12-10.2.1-all.jar") \
    .config("spark.mongodb.write.connection.uri", "mongodb://127.0.0.1:27017/projet_amazon") \
    .getOrCreate()

# %%
df.write \
    .format("mongo") \
    .mode("append") \
    .option("uri", "mongodb://127.0.0.1:27017/projet_amazon.projet_amazon") \
    .save()

# %%
df_mongo = spark.read \
    .format("mongo") \
    .option("uri", "mongodb://127.0.0.1:27017/projet_amazon.projet_amazon") \
    .load()

# Affichage
df_mongo.show(5)
# Out:
# +--------------------+----------+-------+--------------------+-----------+--------------+----------------+--------------------+--------------+--------+----+
# |                 _id|      asin|overall|          reviewText| reviewTime|    reviewerID|    reviewerName|             summary|unixReviewTime|verified|vote|
# +--------------------+----------+-------+--------------------+-----------+--------------+----------------+--------------------+--------------+--------+----+
# |{682cd9d9d3ed4816...|B017O9P72A|    1.0|alexa is not able...|12 11, 2015|A27BTSGLXK2C5K|Jacob M. Wessler|very buggy doesnt...|    1449792000|       0|   0|
# |{682cd9d9d3ed4816...|B017O9P72A|    4.0|alexa works great...| 12 8, 2015|A27ZJ1NCBFP1HZ|            Greg|      so far so good|    1449532800|       0|   5|
# |{682cd9d9d3ed4816...|B017O9P72A|    1.0|weak\n\nalexa doe...| 12 7, 2015| ACCQIOZMFN4UK|        Da-Gr8-1|         time waster|    1449446400|       0|  11|
# |{682cd9d9d3ed4816...|B017O9P72A|    2.0|can only control ...| 12 5, 2015|A3KUPJ396OQF78|   Larry Russlin|               buggy|    1449273600|       0|   0|
# |{682cd9d9d3ed4816...|B017O9P72A|    1.0|this worked great...| 02 2, 2018|A1U1RE1ZI19E1H|         Rebekah|     stopped working|    1517529600|       0|   2|
# +--------------------+----------+-------+--------------------+-----------+--------------+----------------+--------------------+--------------+--------+----+
# only showing top 5 rows

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
df1 = spark.read \
    .format("com.mongodb.spark.sql.DefaultSource") \
    .option("uri", "mongodb://127.0.0.1:27017/projet_amazon.projet_amazon") \
    .load()

# %%
df1 = spark.read \
    .format("com.mongodb.spark.sql.DefaultSource") \
    .option("uri", "mongodb://127.0.0.1:27017/projet_amazon.projet_amazon")\
    .load()

# %%
df2 = df1.limit(500000).toPandas()
display(pandas_df)
# Out:
#     overall vote  verified   reviewTime      reviewerID        asin  \
# 0       1.0    0         0  12 11, 2015  A27BTSGLXK2C5K  B017O9P72A
# 1       4.0    5         0   12 8, 2015  A27ZJ1NCBFP1HZ  B017O9P72A
# 2       1.0   11         0   12 7, 2015   ACCQIOZMFN4UK  B017O9P72A
# 3       2.0    0         0   12 5, 2015  A3KUPJ396OQF78  B017O9P72A
# 4       1.0    2         0   02 2, 2018  A1U1RE1ZI19E1H  B017O9P72A
# 5       5.0    0         0  01 15, 2018  A3TXR8GLKS19RE  B017O9P72A
# 6       1.0    4         0   01 5, 2018   AVIWE1LJXCG77  B017O9P72A
# 7       1.0    2         0   01 4, 2018  A1FOHYK23FJ6CN  B017O9P72A
# 8       1.0    5         0  12 30, 2017  A1RRDX9AOST1AN  B017O9P72A
# 9       1.0    5         0  12 29, 2017   AA4DHYT5YSSIT  B017O9P72A
# 10      3.0    9         0  12 29, 2017  A3TYO7I2GSCH4X  B017O9P72A
# 11      5.0    2         0  12 25, 2017  A3KWZMO1A9TO3Z  B017O9P72A
# 12      5.0    2         0  12 18, 2017  A1QBG1TTQZGJNM  B017O9P72A
# 13      2.0    6         0  11 28, 2017  A2NGABQTU93H28  B017O9P72A
# 14      5.0    0         0  11 24, 2017  A2LNJJWW2TLL00  B017O9P72A
# 15      1.0    3         0  11 23, 2017  A1M5UIUZ2P5FFO  B017O9P72A
# 16      1.0    2         0  11 10, 2017   AE5S7XRYMZ15P  B017O9P72A
# 17      4.0    5         0  10 19, 2017  A18JLUE8V4G7TX  B017O9P72A
# 6        Pete Johnson        pretty crappy wonrsquot connect with alexis
# 7    L. Ray Humphreys      not happy can not connect to alexa regardless
# 8               Viola  can not connect a hue lights to alexa linked t...
# 9           angie anj  the service works with google home but doesnt ...
# 10    Amazon Customer  the lifx bulb is awesome this skill is not so ...
# 11    Amazon Customer  so easy to connect and irsquom having way too ...
# 12            Artyhow  i use ldquoechordquo as the wake word  i say l...
# 13              noura                    canrsquot connect lifx to alexa
# 14            jarhead  i havent had any issues  with this skill like ...
# 15    Amazon Customer  this app forces you to use the old invocation ...
# 16       Karim Moussa              red all steps and did all not working
# 17        Uncle Rusty  this skill works just fine though i think a lo...
# 18    Amazon Customer  who would think you would have to spend so muc...
# 19                 RS  lifx is a weird word to say  be so much better...
# 20            edupunk  i have to tell alexa to tell lifx to do things...
# 21            RobertP                              the title says it all
# 22     Mageswari Babu                                               good
# 23    Amazon Customer  im giving this five stars because i can now ju...
# 24                  T  once i got used to it to how to say the comman...
# 25    Amazon Customer  so far i have no issues connecting lifx bulbs ...
# 26            Chasser  as others have stated you cannot control the l...
# 27               G.B.  when giving instructions alexa asks which ligh...
# 28            DiepJDS                                        messagenull
# 29          GamingGuy  i wish i was able to say  alexa tell lifx net ...
# 30      Casey Michael                   unable to link account pointless
# 31  Alessandro Fadini  when trying to link an account a line of code ...
# 32       Tushar Joshi  logout of your lifx account and link it fron a...
# 33              Trent  i get an error when trying to link my account ...
# 34             Andrew  cant authorize my account gives me an error us...
# 35    Amazon Customer  remember there are two skills you must setup f...
# 36    Michele M Young  thanks to another reviewer i finally figured t...
# 37              Jacob  ive had the lifx bulbs for two weeks and they ...
# 38                Agi  i linked lifx through  the alexa smart home wi...
# 39      Ashley Walker  i had this enabled but then disabled it  upon ...
# 40     Jack Caravanos  i love my lifx bulbs but this skill still need...
# 41       AuggieDoggie  null message fixed by logging out log out and ...
# 42          C. Wright  will not authorize gettting a null message lik...
# 43        David Allen  horrific lights lose link at least once per da...
# 44         Kimberly G  love my lifx bulbs i have them in my bedroom a...
# 45       Charles Hall  see joey kot dec 28th review  once i logged ou...
# 46               Mark  cannot authorize on my android tablet  it give...
# 47               Hilo  doesnt work on android when you try to authori...
# 48    Jennifer McCabe                   cant link account just says null
# 49         SNITBENDER  good skill but many times some lights dont go ...
#
#                                               summary  unixReviewTime
# 0                              very buggy doesnt work      1449792000
# 1                                      so far so good      1449532800
# 2                                         time waster      1449446400
# 3                                               buggy      1449273600
# 4                                     stopped working      1517529600
# 5                                               great      1515974400
# 6                                        returning to      1515110400
# 7                             can not connect to echo      1515024000
# 8                               connecting is a no go      1514592000
# 9                                       does not work      1514505600
# 10                                     almost awesome      1514505600
# 11                                    this is awesome      1514160000
# 12                                     alexa and lifx      1513555200
# 13                                         really bad      1511827200
# 14                                            love it      1511481600
# 15                                  use the other app      1511395200
# 16  i canrsquot connect to alexia connected to lif...      1510272000
# 17  this skill works just fine though i think a lo...      1508371200
# 18                                           pathetic      1505260800
# 19                                            not bad      1503446400
# 20                       commands need to get shorter      1500854400
# 21                        update breaks functionality      1500768000
# 22                       hooked it up today with ease      1498694400
# 23                                        works great      1491523200
# 24                                        works great      1490659200
# 25          takes more steps than other smart devices      1489708800
# 26                                             usless      1489363200
# 27                                    poorly executed      1489276800
# 28                                cannot link account      1488758400
# 29                                   great lights but      1488758400
# 30                   unable to link account pointless      1488585600
# 31                             linking account broken      1488240000
# 32                       works great null error fixed      1487548800
# 33                              error when connecting      1487376000
# 34                               cant link my account      1487289600
# 35                                        works great      1486944000
# 36                                     figured it out      1485302400
# 37                                   need to fix this      1485043200
# 38                             linking sccount failed      1484697600
# 39                                             issues      1483920000
# 40                    problems with colors and scenes      1483833600
# 41                        log out to fix null message      1483574400
# 42                               not working properly      1483401600
# 43                         too many connection errors      1483315200
# 44                 love lifxim now one of the jetsons      1483228800
# 45                                   fix null message      1483056000
# 46                                   cannot authorize      1483056000
# 47                                        doesnt work      1482969600
# 48                                               null      1482969600
# 49                                    works sometimes      1482969600

# %% [markdown]
# # PLOT OF SENTIMENT OF REVIEWS

# %%
#Fethching data for below analyzation

# ratings = df.groupBy('overall').count().orderBy('overall')

# ratings_pd = ratings.toPandas()

#I commented the Code because i have retrieved the output and stored it in csv for my easiness.

# %%
#Converting the dataframe to csv for future use

#ratings_pd.to_csv('C:\Users\Administrator.TAYYAB-JMP-DEMO\Desktop\Distribution_Overall_Dataset.csv', index=False)

# %%
import seaborn as sns

# %%
# This analysis tells about the sentiment of Reviews in the dataset by checking overall column. As there are ratings in the overall so this
# this histogram tell us that most of the products are reviewed positively and the distribution of Product ratings
# if we analyze according to the overall column.
# I read the csv I made above for Matplot

ratings_pd=pd.read_csv('Distribution_Overall_Dataset.csv')

sns.set(style="darkgrid") 
fig, ax = plt.subplots(figsize=(8, 6))

ax.hist(ratings_pd['overall'], bins=5, range=(0.5, 5.5), weights=ratings_pd['count'],
        color='#86bf91', edgecolor='#383838', alpha=0.8)

ax.set_xlabel('Overall Rating', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
ax.set_title('Distribution of Product Ratings', fontsize=16)

ax.grid(True, alpha=0.5)
ax.tick_params(axis='both', which='major', labelsize=12)

plt.show()
#Most of the products of dataset are reviewed 5 rated.

# %% [markdown]
# # SCATTER PLOT OF REVIEWS VS REVIEW LENGTH

# %%
import seaborn as sns

df2['review_len'] = df2['reviewText'].str.len()
sns.scatterplot(data = df2, x = 'review_len', y = 'overall')
plt.title('Rating vs. Review Length')
plt.xlabel('Review Length')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# # TOP 10 MOST REVIEWED PRODUCTS

# %%
# Here I have grouped data according to the most reviews on a product to check top 10 products according to number of reviews
# of the products.
from pyspark.sql.functions import *

review_counts = df1.groupBy('asin').agg(count('*').alias('review_count'))

# Sort the results in descending order by review count and take the top 10 products
top_10_products = review_counts.orderBy(desc('review_count')).limit(10)

# Join the top 10 products with the original DataFrame to obtain their average overall rating
average_overall = top_10_products.join(df, 'asin').groupBy('asin').agg(avg('overall').alias('avg_overall'))

# Show the results
average_overall.show()


 
 # Here I have top 10 products with most reviews. Below I calculated avg overall of top 10 products.
# Out:
# +----------+------------------+
# |      asin|       avg_overall|
# +----------+------------------+
# |B00CYQP3AK| 4.303808648954211|
# |B010OYASRG| 4.400960089701812|
# |0007420412| 4.491313850521619|
# |0099911701| 4.590658035396128|
# |0141353678| 4.681788105761851|
# |0297859382| 3.891026781742148|
# |0312577222| 4.783670125614418|
# |038568231X|  4.04091143594153|
# |0553418025| 4.632273822490675|
# |B000X1MX7E|4.0529619941529464|
# +----------+------------------+

# %%
# Above I analyzed top 10 products according to the number of reviews and now I will plot a graph to analyze the sentiment of the 
# top 10 products to see if the most reviewed products were good for people or not and this analyzation will also tell us that if
# the most reviewed products will be more profitable and beneficial in future or not.
# I will analyze the sentiment of top 10 products reviewed using the overall column cause it tells us what people rated the product.
# I will take the average overall of the products to conclude whether product will be beneficial in future or not.


#Getting the Average overall for the top 10 products
#average_overall = top10Products.join(df, 'asin').groupBy('asin').agg(avg('overall').alias('avg_overall'))

#Below I will convert in to pandas then to csv for future use.

#Conversion to Pandas
#avgPd=average_overall.toPandas()

#Conversion of data Frame to csv for future use
#avgPd.to_csv('C:\Users\Administrator.TAYYAB-JMP-DEMO\Desktop\Average_Sentiment.csv', index=False)


# Reading the csv I made
avgPd = pd.read_csv('Average_Sentiment.csv')

plt.bar(avgPd["asin"], avgPd["avg_overall"])

plt.title('Average Overall Rating of Top 10 Most Reviewed Products')
plt.xlabel('Product ID')
plt.ylabel('Average Overall Rating')

plt.xticks(rotation=90)

plt.show()

#Below you can see how much the top 10 reviewed products are rated on average.


#I have commented the code because i have stored the outputs in csv files for plotting.

# %% [markdown]
# # TOP 10 LEAST REVIEWED PRODUCTS

# %%
# Now I will fetch the data of top 10 most least reviewed number products and check if the rating they got was good or bad
# and will they be beneficial for future or not.
# This will give me the sentiment that whether customers likes the product or not.

from pyspark.sql.functions import *

reC = df1.groupBy('asin').agg(count('*').alias('newC'))


src = reC.orderBy("newC")

# Only getting first 10 rows and the rows are in sorted order.
lst = src.limit(10)

# Fetching the average overall of the least reviewed products.
res = lst.join(df, 'asin').groupBy('asin').agg(avg('overall').alias('avg_overall'))

# %%
#Converting spark dataframe to pandas
#leastProd=res.toPandas()

# %%
#Stored it in to dataframe 
#leastProd.to_csv('C:\Users\Administrator.TAYYAB-JMP-DEMO\Desktop\Least_Average_Sentiment.csv')

# %%
lstProd = pd.read_csv('Least_Average_Sentiment.csv')

lstProd['asin'] = lstProd['asin'].astype(str)

plt.bar(lstProd['asin'], lstProd["avg_overall"])

plt.title('Average Overall Rating of Top 10 Least Reviewed Products')
plt.xlabel('Product ID')
plt.ylabel('Average Overall Rating')

plt.xticks(rotation=90)

plt.show()

# So as can be seen products with less number of reviews are rated at the average of 5 but as seen in graph there are two products
# 1048775 is averagely rated 2 and 95699 is rated averagely 3 so these products are not that good for money.
